# %% [markdown]
# <a href="https://colab.research.google.com/github/suryamanikanta66/fmml-226Q1A4225/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-27 14:21:01--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   156MB/s    in 0.4s
#
# 2024-03-27 14:21:01 (156 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 40840  1502.00094v1  The rise in popularity of microblogging servic...    cs
# 38598   1111.5135v1  Biometric technologies are the foundation of p...    cs
# 32362  1502.07617v1  We study a general class of online learning pr...    cs
# 32727  1504.02824v2  Co-occurrence Data is a common and important i...    cs
# 12908   1106.4333v1  Probabilistic principal component analysis (PP...  stat
# ...             ...                                                ...   ...
# 19459   1107.0048v1  In this paper, we confront the problem of appl...    cs
# 268    1506.06646v2  Human infants can discover words directly from...    cs
# 10775   1402.4653v1  We study the task of retrieving relevant exper...  stat
# 21673   0810.0901v2  Many problems of low-level computer vision and...  stat
# 11037   1311.6334v1  The problem of searching for experts in a give...    cs
#
#                                                    title  year  \
# 40840                    Twitter Hash Tag Recommendation  2015
# 38598  A New IRIS Normalization Process For Recogniti...  2011
# 32362  Online Learning with Feedback Graphs: Beyond B...  2015
# 32727  A Deep Embedding Model for Co-occurrence Learning  2015
# 12908                        Residual Component Analysis  2011
# ...                                                  ...   ...
# 19459  Reinforcement Learning for Agents with Many Se...  2011
# 268    Nonparametric Bayesian Double Articulation Ana...  2015
# 10775  Retrieval of Experiments by Efficient Estimati...  2014
# 21673  Large Scale Variational Inference and Experime...  2008
# 11037       Learning Reputation in an Authorship Network  2013
#
#                                                 keywords
# 40840  [popularity, microblogging, increased, annotat...
# 38598  [biometric, technologies, foundation, identifi...
# 32362  [specified, prediction, necessarily, structure...
# 32727  [occurrence, important, information, occurrenc...
# 12908  [probabilistic, principal, component, dimensio...
# ...                                                  ...
# 19459  [reinforcement, environment, actuators, autono...
# 268    [unsegmented, explicitly, nonparametric, artic...
# 10775  [retrieving, experiments, experiment, experime...
# 21673  [processing, denoising, deconvolution, tomogra...
# 11037  [searching, important, publications, dirichlet...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 40840    [popularity, microblogging, increased, annotat...
# 38598    [biometric, technologies, foundation, identifi...
# 32362    [specified, prediction, necessarily, structure...
# 32727    [occurrence, important, information, occurrenc...
# 12908    [probabilistic, principal, component, dimensio...
#                                ...
# 16506    [automatic, recognition, typically, punctuatio...
# 11968    [stochastic, recursive, algorithm, employing, ...
# 23148    [recognition, euclidean, similarity, measureme...
# 24971    [recognition, performance, technique, developi...
# 31037    [particular, convolutional, compelling, resolu...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8826 words.
# Out of those 4569 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6d2617f8-6a5b-43f2-80cb-2e53b39531dc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6d2617f8-6a5b-43f2-80cb-2e53b39531dc")) {                    Plotly.newPlot(                        "6d2617f8-6a5b-43f2-80cb-2e53b39531dc",                        [{"x":["investigate","algorithms","increased","recommending","challenging","including","popularity","preprocessing","processing","mechanism","encourage","microblogging","classification","determine","visibility","infrequent","widespread","recommendation","strategies","annotation","challenges","effective","streaming","extracted","encouraging","technologies","segmentation","biometric","authenticate","identification","transform","extraction","possessed","detection","experimental","normalization","technique","techniques","individual","convolving","performance","quantized","acquisition","cryptography","boundaries","walkthrough","cryptographic","correlation","normalized","foundation","measurement","registration","recognition","underlying","unobservable","specified","difficulty","independence","monitoring","prediction","specifically","connections","observable","structure","necessarily","intractable","conditional","different","likelihood","occurrence","equivalent","propagation","probabilistic","consequence","furthermore","probability","interestingly","observation","application","boltzmann","commercial","partition","naturally","objective","difficulties","structured","dependency","experiments","important","information","factorization","motivated","sentences","comparable","transaction","categories","restricted","developed","embedding","clustering","covariance","explained","covariates","algorithm","illustrate","independent","decompose","representation","situation","principal","generalized","component","spherical","canonical","partially","components","expression","eigenvalue","framework","dimensional","correlations","neighbour","relevance","processed","considering","determining","classified","available","comparison","definition","generation","principle","closeness","implemented","knowledge","interpretability","differently","addresses","identifying","explaining","integrates","classifier","constraint","discovered","preferably","discriminative","leverages","automatically","evaluation","accompanying","semantically","representative","multimodal","supervised","descriptive","meaningful","supervision","associated","stipulate","discovering","generated","demonstrates","recognizable","efficiency","dimension","architecture","calculating","competitive","parameter","iteration","character","appropriate","parameters","adaptation","presented","handwritten","innovations","increasing","recurrent","sequences","expresses","selection","answering","paraphrase","sensitive","capturing","consistently","achieving","linguistic","paraphrases","expressions","engineering","computational","clarifying","terminology","demonstrated","importance","specialised","principles","lexicography"],"y":[141,591,48,4,271,236,28,26,265,93,15,2,516,69,12,3,16,36,94,65,115,241,11,125,19,34,214,9,2,100,59,152,1,357,355,29,264,384,113,3,896,10,41,2,34,2,4,70,21,19,39,28,383,124,5,38,38,22,39,225,190,52,24,358,26,33,104,772,65,35,61,93,163,23,176,175,18,60,225,20,18,27,56,162,27,94,49,639,342,736,46,68,78,87,3,64,48,196,114,143,20,18,2,774,62,133,11,373,28,38,79,109,10,27,43,106,44,2,550,190,23,8,33,29,65,39,26,279,128,38,139,43,2,106,347,16,11,51,93,13,21,143,86,23,1,109,35,191,293,7,37,40,43,203,19,54,45,108,1,28,181,65,2,160,83,249,15,135,98,43,54,72,247,55,192,34,11,119,143,97,6,160,50,6,56,43,44,92,72,3,33,44,289,4,9,89,91,6,31,2],"type":"bar"},{"x":["investigate","algorithms","increased","recommending","challenging","including","popul ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4569,), (4569, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8208333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Semi</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>supervised</span> <span style=''>sequence</span> <span style=''>tagging</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.5999999999999999);'>bidirectional</span> <span style=''>language</span> <span style=''>models</span> <br/><br/><span style=''>Pre</span> <span style=''>trained</span> <span style=''>word</span> <span style='background-color:rgba(0, 255, 0, 0.3263157894736843);'>embeddings</span> <span style=''>learned</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unlabeled</span> <span style=''>text</span> <span style=''>have</span> <span style=''>become</span> <span style=''>a</span> <span style=''>standard</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>component</span> <span style=''>of</span> <span style=''>neural</span> <span style=''>network</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>architectures</span> <span style=''>for</span> <span style=''>NLP</span> <span style=''>tasks</span> <span style=''>However</span> <span style=''>in</span> <span style=''>most</span> <span style=''>cases</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.4228855721393036);'>recurrent</span> <span style=''>network</span> <span style=''>that</span> <span style=''>operates</span> <span style=''>on</span> <span style=''>word</span> <span style=''>level</span> <span style='background-color:rgba(0, 255, 0, 0.3743016759776536);'>representations</span> <span style=''>to</span> <span style=''>produce</span> <span style=''>context</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sensitive</span> <span style='background-color:rgba(0, 255, 0, 0.3743016759776536);'>representations</span> <span style=''>is</span> <span style=''>trained</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relatively</span> <span style=''>little</span> <span style=''>labeled</span> <span style=''>data</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrate</span> <span style=''>a</span> <span style=''>general</span> <span style=''>semi</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>supervised</span> <span style=''>approach</span> <span style=''>for</span> <span style=''>adding</span> <span style=''>pre</span> <span style=''>trained</span> <span style=''>context</span> <span style='background-color:rgba(0, 255, 0, 0.3263157894736843);'>embeddings</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.5999999999999999);'>bidirectional</span> <span style=''>language</span> <span style=''>models</span> <span style=''>to</span> <span style=''>NLP</span> <span style=''>systems</span> <span style=''>and</span> <span style=''>apply</span> <span style=''>it</span> <span style=''>to</span> <span style=''>sequence</span> <span style=''>labeling</span> <span style=''>tasks</span> <span style=''>We</span> <span style=''>evaluate</span> <span style=''>our</span> <span style=''>model</span> <span style=''>on</span> <span style=''>two</span> <span style=''>standard</span> <span style=''>datasets</span> <span style=''>for</span> <span style=''>named</span> <span style=''>entity</span> <span style='background-color:rgba(0, 255, 0, 0.6160337552742617);'>recognition</span> <span style=''>(NER)</span> <span style=''>and</span> <span style=''>chunking</span> <span style=''>and</span> <span style=''>in</span> <span style=''>both</span> <span style=''>cases</span> <span style=''>achieve</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>results</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>surpassing</span> <span style=''>previous</span> <span style=''>systems</span> <span style=''>that</span> <spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style=''>Bayesian</span> <span style=''>index</span> <span style=''>policies</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sequential</span> <span style=''>resource</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>allocation</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>is</span> <span style=''>about</span> <span style=''>index</span> <span style=''>policies</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>minimizing</span> <span style=''>(frequentist)</span> <span style=''>regret</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>multi</span> <span style=''>armed</span> <span style=''>bandit</span> <span style=''>model</span> <span style=''>inspired</span> <span style=''>by</span> <span style=''>a</span> <span style=''>Bayesian</span> <span style=''>view</span> <span style=''>on</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>Our</span> <span style=''>main</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>contribution</span> <span style=''>is</span> <span style=''>to</span> <span style=''>prove</span> <span style=''>that</span> <span style=''>the</span> <span style=''>Bayes</span> <span style=''>UCB</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>which</span> <span style=''>relies</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>quantiles</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>posterior</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>asymptotically</span> <span style=''>optimal</span> <span style=''>when</span> <span style=''>the</span> <span style=''>reward</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>belong</span> <span style=''>to</span> <span style=''>a</span> <span style=''>one</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exponential</span> <span style=''>family</span> <span style=''>for</span> <span style=''>a</span> <span style=''>large</span> <span style=''>class</span> <span style=''>of</span> <span style=''>prior</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>We</span> <span style=''>also</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>literature</span> <span style=''>gives</span> <span style=''>new</span> <span style=''>insight</span> <span style=''>on</span> <span style=''>what</span> <span style=''>kind</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exploration</span> <span style=''>rates</span> <span style=''>could</span> <span style=''>be</span> <span style=''>used</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>frequentist</span> <span style=''>UCB</span> <span style=''>type</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>Indeed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximations</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Bayesian</span> <span style=''>optimal</span> <span style=''>solution</span> <span style=''>or</span> <span style=''>the</span> <span style=''>Finite</span> <span style=''>Horizon</span> <span style=''>Gittins</span> <span style=''>indices</span> <span style=''>provide</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>justification</span> <span style=''>for</span> <sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.5714285714285714);'>Nonconvex</span> <span style=''>Sparse</span> <span style=''>Learning</span> <span style=''>via</span> <span style='background-color:rgba(255, 0, 0, 0.36764705882352944);'>Stochastic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Optimization</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.8333333333333333);'>Progressive</span> <span style=''>Variance</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Reduction</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.36764705882352944);'>stochastic</span> <span style=''>variance</span> <span style=''>reduced</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>solving</span> <span style=''>sparse</span> <span style=''>learning</span> <span style=''>problems</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>cardinality</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraints</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Sufficient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>are</span> <span style=''>provided</span> <span style=''>under</span> <span style=''>which</span> <span style=''>the</span> <span style=''>proposed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>enjoys</span> <span style=''>strong</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.3313953488372094);'>convergence</span> <span style='background-color:rgba(255, 0, 0, 0.3167701863354037);'>guarantees</span> <span style=''>and</span> <span style=''>optimal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>accuracy</span> <span style=''>in</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dimensions</span> <span style=''>We</span> <span style=''>further</span> <span style=''>extend</span> <span style=''>the</span> <span style=''>proposed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>to</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>asynchronous</span> <span style=''>parallel</span> <span style=''>variant</span> <span style=''>with</span> <span style=''>a</span> <span style=''>near</span> <span style=''>linear</span> <span style=''>speedup</span> <span style='background-color:rgba(255, 0, 0, 0.44483985765124556);'>Numerical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>experiments</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrate</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficiency</span> <span style=''>of</span> <span style=''>our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>both</span> <span style='background-color:rgba(255, 0, 0, 0.4042553191489362);'>parameter</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Deep</span> <span style=''>BCD</span> <span style=''>Net</span> <span style=''>Using</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Identical</span> <span style=''>Encoding</span> <span style=''>Decoding</span> <span style=''>CNN</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Structures</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Iterative</span> <span style=''>Image</span> <span style=''>Recovery</span> <br/><br/><span style=''>In</span> <span style=''>extreme</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style=''>imaging</span> <span style=''>that</span> <span style=''>collects</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extremely</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>undersampled</span> <span style=''>or</span> <span style=''>noisy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>measurements</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>obtaining</span> <span style=''>an</span> <span style=''>accurate</span> <span style=''>image</span> <span style=''>within</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reasonable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computing</span> <span style=''>time</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenging</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Incorporating</span> <span style=''>image</span> <span style=''>mapping</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convolutional</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>(CNN)</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iterative</span> <span style=''>image</span> <span style=''>recovery</span> <span style=''>has</span> <span style=''>great</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>potential</span> <span style=''>to</span> <span style=''>resolve</span> <span style=''>this</span> <span style=''>issue</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>1)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incorporates</span> <span style=''>image</span> <span style=''>mapping</span> <span style=''>CNN</span> <span style=''>using</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>identical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convolutional</span> <span style=''>kernels</span> <span style=''>in</span> <span style=''>both</span> <span style=''>encoders</span> <span style=''>and</span> <span style=''>decoders</span> <span style=''>into</span> <span style=''>block</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>coordinate</span> <span style=''>descent</span> <span style=''>(BCD)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>method</span> <span style=''>referred</span> <span style=''>to</span> <span style=''>BCD</span> <span style=''>Net</span> <span style=''>using</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>identical</span> <span style=''>encoding</span> <span style=''>decoding</span> <span style=''>CNN</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structures</span> <span style=''>and</span> <span style=''>2)</span> <span style=''>applies</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>alternating</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>direction</span> <span style=''>method</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>multipliers</span> <span style=''>to</span> <span style=''>train</span> <span style=''>the</span> <span style=''>proposed</span> <span style=''>BCD</span> <span style=''>Net</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Numerical</span> <span style='background-color:rgba(255, 0, 0, 0. ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.12468559108875314)
# 	experimental (0.1275601868487244)
# 	evaluation (0.10528206970894718)
# 	segmentation (0.07689543657923105)
# 	representation (0.13402802730865973)
# 	information (0.2644628099173554)
# 	detection (0.1282788357887172)
# 	different (0.277398490837226)
# 	convolutional (0.13546532518864535)
# 	recognition (0.13762127200862379)
#
# Some Statistics words are:
# 	algorithm (0.36489836390679226)
# 	variables (0.14030738720872582)
# 	stochastic (0.1383242439266237)
# 	theoretical (0.14625681705503224)
# 	estimation (0.1700545364402578)
# 	statistical (0.15666831928606842)
# 	distribution (0.18244918195339613)
# 	dimensional (0.1923648983639068)
# 	inference (0.20277640059494298)
# 	regression (0.1700545364402578)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="af048153-e346-4b73-bdd2-1572c36f2de2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("af048153-e346-4b73-bdd2-1572c36f2de2")) {                    Plotly.newPlot(                        "af048153-e346-4b73-bdd2-1572c36f2de2",                        [{"x":["investigate","algorithms","increased","recommending","challenging","including","popularity","preprocessing","processing","mechanism","encourage","microblogging","classification","determine","visibility","infrequent","widespread","recommendation","strategies","annotation","challenges","effective","streaming","extracted","encouraging","technologies","segmentation","biometric","authenticate","identification","transform","extraction","possessed","detection","experimental","normalization","technique","techniques","individual","convolving","performance","quantized","acquisition","cryptography","boundaries","walkthrough","cryptographic","correlation","normalized","foundation","measurement","registration","recognition","underlying","unobservable","specified","difficulty","independence","monitoring","prediction","specifically","connections","observable","structure","necessarily","intractable","conditional","different","likelihood","occurrence","equivalent","propagation","probabilistic","consequence","furthermore","probability","interestingly","observation","application","boltzmann","commercial","partition","naturally","objective","difficulties","structured","dependency","experiments","important","information","factorization","motivated","sentences","comparable","transaction","categories","restricted","developed","embedding","clustering","covariance","explained","covariates","algorithm","illustrate","independent","decompose","representation","situation","principal","generalized","component","spherical","canonical","partially","components","expression","eigenvalue","framework","dimensional","correlations","neighbour","relevance","processed","considering","determining","classified","available","comparison","definition","generation","principle","closeness","implemented","knowledge","interpretability","differently","addresses","identifying","explaining","integrates","classifier","constraint","discovered","preferably","discriminative","leverages","automatically","evaluation","accompanying","semantically","representative","multimodal","supervised","descriptive","meaningful","supervision","associated","stipulate","discovering","generated","demonstrates","recognizable","efficiency","dimension","architecture","calculating","competitive","parameter","iteration","character","appropriate","parameters","adaptation","presented","handwritten","innovations","increasing","recurrent","sequences","expresses","selection","answering","paraphrase","sensitive","capturing","consistently","achieving","linguistic","paraphrases","expressions","engineering","computational","clarifying","terminology","demonstrated","importance","specialised","principles","lexicography","implementation","traditional","standards","examining","conceptual","describing","mathematical","applications","emergence","perspective","representations","transition","convolutional","denoising","perceptron","geographical","performances","neighborhood","predictive","satellite","incorporate","characteristics","autoencoder","outperforms","nonetheless","enhancement","combining","simulates","autoencoders","alternative","solutions","approaches","practical","successful","implementing","negligible","satisfiability","described","satisfiable","optimizers","validating","paramount","preliminary","organizations","complements","confidence","iterative","unsatisfiable","optimization","validation","correctly","estimates","estimated","segmentations","micro ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	diagonalization
# 	faithfulness
# 	archetypes
# 	archetypal
# 	smoothers
# 	lindenstrauss
# 	anopheles
# 	gribonval
# 	procrustes
# 	geostatistical
# 	extrapolation
# 	reparameterized
# 	disaggregation
# 	spectrometry
# 	methodologically
# 	acceptancerejection
# 	assortativity
# 	horseshoe
# 	bernsteins
# 	ingenious
# Some words which never appear in Statistics papers:
# 	microblogging
# 	authenticate
# 	walkthrough
# 	paraphrase
# 	paraphrases
# 	clarifying
# 	lexicography
# 	satisfiable
# 	unsatisfiable
# 	epithelial
# 	distinctiveness
# 	paragraphs
# 	blogosphere
# 	voxelized
# 	monocular
# 	relocalization
# 	algorithmically
# 	simplistic
# 	evidential
# 	termination

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0865150158955525e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.775
